# %%
# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from LinearMPC_5.MPCVelControl import MPCVelControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 15; H = 5.0
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 2.0
rocket.fuel_rate = 0.1
t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
# c:\Users\Utilisateur\anaconda3\envs\mpc\Lib\site-packages\cvxpy\problems\problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Simulating time 0.00:
# c:\Users\Utilisateur\anaconda3\envs\mpc\Lib\site-packages\cvxpy\reductions\solvers\solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# dhat =  [24.47481134]
# Fuel left: 1.00 kg,
# Simulating time 0.05: dhat =  [24.47481134]
# Fuel left: 1.00 kg,
# Simulating time 0.10: dhat =  [24.47481134]
# Fuel left: 0.99 kg,
# Simulating time 0.15: dhat =  [24.47481134]
# Fuel left: 0.99 kg,
# Simulating time 0.20: dhat =  [24.47481134]
# Fuel left: 0.99 kg,
# Simulating time 0.25: dhat =  [24.47481134]
#
#  State alpha violation: 0.18 > 0.17, Fuel left: 0.99 kg,
# Simulating time 0.30: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.19 > 0.17, Fuel left: 0.99 kg,
# Simulating time 0.35: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.40: dhat =  [24.47481134]
# Fuel left: 0.98 kg,
# Simulating time 0.45: dhat =  [24.47481134]
# Fuel left: 0.98 kg,
# Simulating time 0.50: dhat =  [24.47481134]
# Fuel left: 0.98 kg,
# Simulating time 0.55: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.60: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.65: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17, Fuel left: 0.97 kg,
# Simulating time 0.70: dhat =  [24.47481134]
# Fuel left: 0.97 kg,
# Simulating time 0.75: dhat =  [24.47481134]
# Fuel left: 0.97 kg,
# Simulating time 0.80: dhat =  [24.47481134]
# Fuel left: 0.97 kg,
# Simulating time 0.85: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17, Fuel left: 0.96 kg,
# Simulating time 0.90: dhat =  [24.47481134]
#
#  State alpha violation: 0.17 > 0.17, Fuel left: 0.96 kg,
# Simulating time 0.95: dhat =  [24.47481134]
# Fuel left: 0.96 kg,
# Simulating time 1.00: dhat =  [24.47481134]
# Fuel left: 0.96 kg,
# Simulating time 1.05: dhat =  [24.47481134]
# Fuel left: 0.96 kg,
# Simulating time 1.10: dhat =  [24.47481134]
# Fuel left: 0.95 kg,
# Simulating time 1.15: dhat =  [24.47481134]
# Fuel left: 0.95 kg,
# Simulating time 1.20: dhat =  [24.47481134]
# Fuel left: 0.95 kg,
# Simulating time 1.25: dhat =  [24.47481134]
# Fuel left: 0.95 kg,
# Simulating time 1.30: dhat =  [24.47481134]
# Fuel left: 0.95 kg,
# Simulating time 1.35: dhat =  [24.47481134]
# Fuel left: 0.94 kg,
# Simulating time 1.40: dhat =  [24.47481134]
# Fuel left: 0.94 kg,
# Simulating time 1.45: dhat =  [24.47481134]
# Fuel left: 0.94 kg,
# Simulating time 1.50: dhat =  [24.47481134]
# Fuel left: 0.94 kg,
# Simulating time 1.55: dhat =  [24.47481134]
# Fuel left: 0.94 kg,
# Simulating time 1.60: dhat =  [24.47481134]
# Fuel left: 0.93 kg,
# Simulating time 1.65: dhat =  [24.47481134]
# Fuel left: 0.93 kg,
# Simulating time 1.70: dhat =  [24.47481134]
# Fuel left: 0.93 kg,
# Simulating time 1.75: dhat =  [24.47481134]
# Fuel left: 0.93 kg,
# Simulating time 1.80: dhat =  [24.47481134]
# Fuel left: 0.93 kg,
# Simulating time 1.85: dhat =  [24.47481134]
# Fuel left: 0.92 kg,
# Simulating time 1.90: dhat =  [24.47481134]
# Fuel left: 0.92 kg,
# Simulating time 1.95: dhat =  [24.47481134]
# Fuel left: 0.92 kg,
# Simulating time 2.00: dhat =  [24.47481134]
# Fuel left: 0.92 kg,
# Simulating time 2.05: dhat =  [24.47481134]
# Fuel left: 0.92 kg,
# Simulating time 2.10: dhat =  [24.47481134]
# Fuel left: 0.91 kg,
# Simulating time 2.15: dhat =  [24.47481134]
# Fuel left: 0.91 kg,
# Simulating time 2.20: dhat =  [24.47481134]
# Fuel left: 0.91 kg,
# Simulating time 2.25: dhat =  [24.47481134]
# Fuel left: 0.91 kg,
# Simulating time 2.30: dhat =  [24.47481134]
# Fuel left: 0.91 kg,
# Simulating time 2.35: dhat =  [23.28285588]
# Fuel left: 0.90 kg,
# Simulating time 2.40: dhat =  [22.11528455]
# Fuel left: 0.90 kg,
# Simulating time 2.45: dhat =  [20.98587159]
# Fuel left: 0.90 kg,
# Simulating time 2.50: dhat =  [19.90282637]
# Fuel left: 0.90 kg,
# Simulating time 2.55: dhat =  [18.87064347]
# Fuel left: 0.89 kg,
# Simulating time 2.60: dhat =  [17.89135383]
# Fuel left: 0.89 kg,
# Simulating time 2.65: dhat =  [16.96537003]
# Fuel left: 0.89 kg,
# Simulating time 2.70: dhat =  [16.09205673]
# Fuel left: 0.89 kg,
# Simulating time 2.75: dhat =  [15.27011459]
# Fuel left: 0.88 kg,
# Simulating time 2.80: dhat =  [14.49783819]
# Fuel left: 0.88 kg,
# Simulating time 2.85: dhat =  [13.77328849]
# Fuel left: 0.88 kg,
# Simulating time 2.90: dhat =  [13.09440757]
# Fuel left: 0.88 kg,
# Simulating time 2.95: dhat =  [12.45909432]
# Fuel left: 0.87 kg,
# Simulating time 3.00: dhat =  [11.86525396]
# Fuel left: 0.87 kg,
# Simulating time 3.05: dhat =  [11.31082943]
# Fuel left: 0.87 kg,
# Simulating time 3.10: dhat =  [10.79382142]
# Fuel left: 0.86 kg,
# Simulating time 3.15: dhat =  [10.31229993]
# Fuel left: 0.86 kg,
# Simulating time 3.20: dhat =  [9.8644111]
# Fuel left: 0.86 kg,
# Simulating time 3.25: dhat =  [9.44775772]
# Fuel left: 0.85 kg,
# Simulating time 3.30: dhat =  [9.05892657]
# Fuel left: 0.85 kg,
# Simulating time 3.35: dhat =  [8.69746391]
# Fuel left: 0.85 kg,
# Simulating time 3.40: dhat =  [8.36363865]
# Fuel left: 0.85 kg,
# Simulating time 3.45: dhat =  [8.05755844]
# Fuel left: 0.84 kg,
# Simulating time 3.50: dhat =  [7.77908992]
# Fuel left: 0.84 kg,
# Simulating time 3.55: dhat =  [7.52786613]
# Fuel left: 0.84 kg,
# Simulating time 3.60: dhat =  [7.30330456]
# Fuel left: 0.83 kg,
# Simulating time 3.65: dhat =  [7.10462877]
# Fuel left: 0.83 kg,
# Simulating time 3.70: dhat =  [6.93089241]
# Fuel left: 0.83 kg,
# Simulating time 3.75: dhat =  [6.7810053]
# Fuel left: 0.82 kg,
# Simulating time 3.80: dhat =  [6.65376042]
# Fuel left: 0.82 kg,
# Simulating time 3.85: dhat =  [6.54786129]
# Fuel left: 0.82 kg,
# Simulating time 3.90: dhat =  [6.46194878]
# Fuel left: 0.81 kg,
# Simulating time 3.95: dhat =  [6.39462665]
# Fuel left: 0.81 kg,
# Simulating time 4.00: dhat =  [6.34448536]
# Fuel left: 0.81 kg,
# Simulating time 4.05: dhat =  [6.31012345]
# Fuel left: 0.80 kg,
# Simulating time 4.10: dhat =  [6.29016645]
# Fuel left: 0.80 kg,
# Simulating time 4.15: dhat =  [6.28328292]
# Fuel left: 0.80 kg,
# Simulating time 4.20: dhat =  [6.28819766]
# Fuel left: 0.79 kg,
# Simulating time 4.25: dhat =  [6.30370206]
# Fuel left: 0.79 kg,
# Simulating time 4.30: dhat =  [6.32866181]
# Fuel left: 0.79 kg,
# Simulating time 4.35: dhat =  [6.36202206]
# Fuel left: 0.79 kg,
# Simulating time 4.40: dhat =  [6.40281027]
# Fuel left: 0.78 kg,
# Simulating time 4.45: dhat =  [6.45013721]
# Fuel left: 0.78 kg,
# Simulating time 4.50: dhat =  [6.50319609]
# Fuel left: 0.78 kg,
# Simulating time 4.55: dhat =  [6.56126034]
# Fuel left: 0.77 kg,
# Simulating time 4.60: dhat =  [6.62368033]
# Fuel left: 0.77 kg,
# Simulating time 4.65: dhat =  [6.68987911]
# Fuel left: 0.77 kg,
# Simulating time 4.70: dhat =  [6.7593476]
# Fuel left: 0.76 kg,
# Simulating time 4.75: dhat =  [6.83163938]
# Fuel left: 0.76 kg,
# Simulating time 4.80: dhat =  [6.90636527]
# Fuel left: 0.76 kg,
# Simulating time 4.85: dhat =  [6.98318784]
# Fuel left: 0.75 kg,
# Simulating time 4.90: dhat =  [7.06181599]
# Fuel left: 0.75 kg,
# Simulating time 4.95: dhat =  [7.14199981]
# Fuel left: 0.75 kg,
# Simulating time 5.00: dhat =  [7.22352559]
# Fuel left: 0.74 kg,
# Simulating time 5.05: dhat =  [7.30621122]
# Fuel left: 0.74 kg,
# Simulating time 5.10: dhat =  [7.38990195]
# Fuel left: 0.74 kg,
# Simulating time 5.15: dhat =  [7.4744665]
# Fuel left: 0.74 kg,
# Simulating time 5.20: dhat =  [7.55979363]
# Fuel left: 0.73 kg,
# Simulating time 5.25: dhat =  [7.64578898]
# Fuel left: 0.73 kg,
# Simulating time 5.30: dhat =  [7.73237239]
# Fuel left: 0.73 kg,
# Simulating time 5.35: dhat =  [7.81947555]
# Fuel left: 0.72 kg,
# Simulating time 5.40: dhat =  [7.90703991]
# Fuel left: 0.72 kg,
# Simulating time 5.45: dhat =  [7.99501498]
# Fuel left: 0.72 kg,
# Simulating time 5.50: dhat =  [8.08335687]
# Fuel left: 0.71 kg,
# Simulating time 5.55: dhat =  [8.17202702]
# Fuel left: 0.71 kg,
# Simulating time 5.60: dhat =  [8.26099127]
# Fuel left: 0.71 kg,
# Simulating time 5.65: dhat =  [8.35021897]
# Fuel left: 0.71 kg,
# Simulating time 5.70: dhat =  [8.43968236]
# Fuel left: 0.70 kg,
# Simulating time 5.75: dhat =  [8.52935601]
# Fuel left: 0.70 kg,
# Simulating time 5.80: dhat =  [8.61921647]
# Fuel left: 0.70 kg,
# Simulating time 5.85: dhat =  [8.70924189]
# Fuel left: 0.69 kg,
# Simulating time 5.90: dhat =  [8.79941183]
# Fuel left: 0.69 kg,
# Simulating time 5.95: dhat =  [8.88970704]
# Fuel left: 0.69 kg,
# Simulating time 6.00: dhat =  [8.98010938]
# Fuel left: 0.69 kg,
# Simulating time 6.05: dhat =  [9.07060168]
# Fuel left: 0.68 kg,
# Simulating time 6.10: dhat =  [9.16116771]
# Fuel left: 0.68 kg,
# Simulating time 6.15: dhat =  [9.25179213]
# Fuel left: 0.68 kg,
# Simulating time 6.20: dhat =  [9.34246043]
# Fuel left: 0.67 kg,
# Simulating time 6.25: dhat =  [9.43315896]
# Fuel left: 0.67 kg,
# Simulating time 6.30: dhat =  [9.52387487]
# Fuel left: 0.67 kg,
# Simulating time 6.35: dhat =  [9.61459611]
# Fuel left: 0.67 kg,
# Simulating time 6.40: dhat =  [9.70531141]
# Fuel left: 0.66 kg,
# Simulating time 6.45: dhat =  [9.79601029]
# Fuel left: 0.66 kg,
# Simulating time 6.50: dhat =  [9.886683]
# Fuel left: 0.66 kg,
# Simulating time 6.55: dhat =  [9.97732052]
# Fuel left: 0.65 kg,
# Simulating time 6.60: dhat =  [10.06791456]
# Fuel left: 0.65 kg,
# Simulating time 6.65: dhat =  [10.15845748]
# Fuel left: 0.65 kg,
# Simulating time 6.70: dhat =  [10.2489423]
# Fuel left: 0.65 kg,
# Simulating time 6.75: dhat =  [10.33936267]
# Fuel left: 0.64 kg,
# Simulating time 6.80: dhat =  [10.42971281]
# Fuel left: 0.64 kg,
# Simulating time 6.85: dhat =  [10.51998749]
# Fuel left: 0.64 kg,
# Simulating time 6.90: dhat =  [10.61018201]
# Fuel left: 0.63 kg,
# Simulating time 6.95: dhat =  [10.70029214]
# Fuel left: 0.63 kg,
# Simulating time 7.00: dhat =  [10.79031409]
# Fuel left: 0.63 kg,
# Simulating time 7.05: dhat =  [10.88024449]
# Fuel left: 0.63 kg,
# Simulating time 7.10: dhat =  [10.97008035]
# Fuel left: 0.62 kg,
# Simulating time 7.15: dhat =  [11.05981899]
# Fuel left: 0.62 kg,
# Simulating time 7.20: dhat =  [11.1494581]
# Fuel left: 0.62 kg,
# Simulating time 7.25: dhat =  [11.2389956]
# Fuel left: 0.62 kg,
# Simulating time 7.30: dhat =  [11.3284297]
# Fuel left: 0.61 kg,
# Simulating time 7.35: dhat =  [11.41775882]
# Fuel left: 0.61 kg,
# Simulating time 7.40: dhat =  [11.50698159]
# Fuel left: 0.61 kg,
# Simulating time 7.45: dhat =  [11.59609683]
# Fuel left: 0.60 kg,
# Simulating time 7.50: dhat =  [11.68510352]
# Fuel left: 0.60 kg,
# Simulating time 7.55: dhat =  [11.77400077]
# Fuel left: 0.60 kg,
# Simulating time 7.60: dhat =  [11.86278784]
# Fuel left: 0.60 kg,
# Simulating time 7.65: dhat =  [11.95146407]
# Fuel left: 0.59 kg,
# Simulating time 7.70: dhat =  [12.04002893]
# Fuel left: 0.59 kg,
# Simulating time 7.75: dhat =  [12.12848194]
# Fuel left: 0.59 kg,
# Simulating time 7.80: dhat =  [12.21682272]
# Fuel left: 0.59 kg,
# Simulating time 7.85: dhat =  [12.30505094]
# Fuel left: 0.58 kg,
# Simulating time 7.90: dhat =  [12.39316633]
# Fuel left: 0.58 kg,
# Simulating time 7.95: dhat =  [12.48116867]
# Fuel left: 0.58 kg,
# Simulating time 8.00: dhat =  [12.56905775]
# Fuel left: 0.57 kg,
# Simulating time 8.05: dhat =  [12.65683344]
# Fuel left: 0.57 kg,
# Simulating time 8.10: dhat =  [12.74449561]
# Fuel left: 0.57 kg,
# Simulating time 8.15: dhat =  [12.83204414]
# Fuel left: 0.57 kg,
# Simulating time 8.20: dhat =  [12.91947896]
# Fuel left: 0.56 kg,
# Simulating time 8.25: dhat =  [13.0068]
# Fuel left: 0.56 kg,
# Simulating time 8.30: dhat =  [13.0940072]
# Fuel left: 0.56 kg,
# Simulating time 8.35: dhat =  [13.18110053]
# Fuel left: 0.56 kg,
# Simulating time 8.40: dhat =  [13.26807993]
# Fuel left: 0.55 kg,
# Simulating time 8.45: dhat =  [13.35494539]
# Fuel left: 0.55 kg,
# Simulating time 8.50: dhat =  [13.44169686]
# Fuel left: 0.55 kg,
# Simulating time 8.55: dhat =  [13.52833433]
# Fuel left: 0.55 kg,
# Simulating time 8.60: dhat =  [13.61485778]
# Fuel left: 0.54 kg,
# Simulating time 8.65: dhat =  [13.70126718]
# Fuel left: 0.54 kg,
# Simulating time 8.70: dhat =  [13.7875625]
# Fuel left: 0.54 kg,
# Simulating time 8.75: dhat =  [13.87374372]
# Fuel left: 0.54 kg,
# Simulating time 8.80: dhat =  [13.95981082]
# Fuel left: 0.53 kg,
# Simulating time 8.85: dhat =  [14.04576376]
# Fuel left: 0.53 kg,
# Simulating time 8.90: dhat =  [14.13160252]
# Fuel left: 0.53 kg,
# Simulating time 8.95: dhat =  [14.21732706]
# Fuel left: 0.53 kg,
# Simulating time 9.00: dhat =  [14.30293733]
# Fuel left: 0.52 kg,
# Simulating time 9.05: dhat =  [14.38843331]
# Fuel left: 0.52 kg,
# Simulating time 9.10: dhat =  [14.47381494]
# Fuel left: 0.52 kg,
# Simulating time 9.15: dhat =  [14.55908217]
# Fuel left: 0.52 kg,
# Simulating time 9.20: dhat =  [14.64423496]
# Fuel left: 0.51 kg,
# Simulating time 9.25: dhat =  [14.72927323]
# Fuel left: 0.51 kg,
# Simulating time 9.30: dhat =  [14.81419695]
# Fuel left: 0.51 kg,
# Simulating time 9.35: dhat =  [14.89900603]
# Fuel left: 0.51 kg,
# Simulating time 9.40: dhat =  [14.98370041]
# Fuel left: 0.50 kg,
# Simulating time 9.45: dhat =  [15.06828002]
# Fuel left: 0.50 kg,
# Simulating time 9.50: dhat =  [15.15274479]
# Fuel left: 0.50 kg,
# Simulating time 9.55: dhat =  [15.23709464]
# Fuel left: 0.50 kg,
# Simulating time 9.60: dhat =  [15.32132948]
# Fuel left: 0.49 kg,
# Simulating time 9.65: dhat =  [15.40544924]
# Fuel left: 0.49 kg,
# Simulating time 9.70: dhat =  [15.48945382]
# Fuel left: 0.49 kg,
# Simulating time 9.75: dhat =  [15.57334314]
# Fuel left: 0.49 kg,
# Simulating time 9.80: dhat =  [15.6571171]
# Fuel left: 0.48 kg,
# Simulating time 9.85: dhat =  [15.74077562]
# Fuel left: 0.48 kg,
# Simulating time 9.90: dhat =  [15.82431859]
# Fuel left: 0.48 kg,
# Simulating time 9.95: dhat =  [15.90774593]
# Fuel left: 0.48 kg,
# Simulating time 10.00: dhat =  [15.99105753]
# Fuel left: 0.47 kg,
# Simulating time 10.05: dhat =  [16.07425329]
# Fuel left: 0.47 kg,
# Simulating time 10.10: dhat =  [16.15733311]
# Fuel left: 0.47 kg,
# Simulating time 10.15: dhat =  [16.2402969]
# Fuel left: 0.47 kg,
# Simulating time 10.20: dhat =  [16.32314455]
# Fuel left: 0.46 kg,
# Simulating time 10.25: dhat =  [16.40587595]
# Fuel left: 0.46 kg,
# Simulating time 10.30: dhat =  [16.48849101]
# Fuel left: 0.46 kg,
# Simulating time 10.35: dhat =  [16.57098963]
# Fuel left: 0.46 kg,
# Simulating time 10.40: dhat =  [16.65337169]
# Fuel left: 0.45 kg,
# Simulating time 10.45: dhat =  [16.73563711]
# Fuel left: 0.45 kg,
# Simulating time 10.50: dhat =  [16.81778578]
# Fuel left: 0.45 kg,
# Simulating time 10.55: dhat =  [16.89981759]
# Fuel left: 0.45 kg,
# Simulating time 10.60: dhat =  [16.98173246]
# Fuel left: 0.44 kg,
# Simulating time 10.65: dhat =  [17.06353028]
# Fuel left: 0.44 kg,
# Simulating time 10.70: dhat =  [17.14521096]
# Fuel left: 0.44 kg,
# Simulating time 10.75: dhat =  [17.2267744]
# Fuel left: 0.44 kg,
# Simulating time 10.80: dhat =  [17.30822051]
# Fuel left: 0.43 kg,
# Simulating time 10.85: dhat =  [17.38954919]
# Fuel left: 0.43 kg,
# Simulating time 10.90: dhat =  [17.47076036]
# Fuel left: 0.43 kg,
# Simulating time 10.95: dhat =  [17.55185393]
# Fuel left: 0.43 kg,
# Simulating time 11.00: dhat =  [17.63282981]
# Fuel left: 0.42 kg,
# Simulating time 11.05: dhat =  [17.71368791]
# Fuel left: 0.42 kg,
# Simulating time 11.10: dhat =  [17.79442816]
# Fuel left: 0.42 kg,
# Simulating time 11.15: dhat =  [17.87505048]
# Fuel left: 0.42 kg,
# Simulating time 11.20: dhat =  [17.95555479]
# Fuel left: 0.41 kg,
# Simulating time 11.25: dhat =  [18.03594101]
# Fuel left: 0.41 kg,
# Simulating time 11.30: dhat =  [18.11620908]
# Fuel left: 0.41 kg,
# Simulating time 11.35: dhat =  [18.19635892]
# Fuel left: 0.41 kg,
# Simulating time 11.40: dhat =  [18.27639047]
# Fuel left: 0.41 kg,
# Simulating time 11.45: dhat =  [18.35630367]
# Fuel left: 0.40 kg,
# Simulating time 11.50: dhat =  [18.43609845]
# Fuel left: 0.40 kg,
# Simulating time 11.55: dhat =  [18.51577475]
# Fuel left: 0.40 kg,
# Simulating time 11.60: dhat =  [18.59533253]
# Fuel left: 0.40 kg,
# Simulating time 11.65: dhat =  [18.67477173]
# Fuel left: 0.39 kg,
# Simulating time 11.70: dhat =  [18.75409229]
# Fuel left: 0.39 kg,
# Simulating time 11.75: dhat =  [18.83329418]
# Fuel left: 0.39 kg,
# Simulating time 11.80: dhat =  [18.91237736]
# Fuel left: 0.39 kg,
# Simulating time 11.85: dhat =  [18.99134177]
# Fuel left: 0.38 kg,
# Simulating time 11.90: dhat =  [19.07018739]
# Fuel left: 0.38 kg,
# Simulating time 11.95: dhat =  [19.14891418]
# Fuel left: 0.38 kg,
# Simulating time 12.00: dhat =  [19.22752211]
# Fuel left: 0.38 kg,
# Simulating time 12.05: dhat =  [19.30601115]
# Fuel left: 0.38 kg,
# Simulating time 12.10: dhat =  [19.38438128]
# Fuel left: 0.37 kg,
# Simulating time 12.15: dhat =  [19.46263248]
# Fuel left: 0.37 kg,
# Simulating time 12.20: dhat =  [19.54076473]
# Fuel left: 0.37 kg,
# Simulating time 12.25: dhat =  [19.61877802]
# Fuel left: 0.37 kg,
# Simulating time 12.30: dhat =  [19.69667232]
# Fuel left: 0.36 kg,
# Simulating time 12.35: dhat =  [19.77444764]
# Fuel left: 0.36 kg,
# Simulating time 12.40: dhat =  [19.85210397]
# Fuel left: 0.36 kg,
# Simulating time 12.45: dhat =  [19.9296413]
# Fuel left: 0.36 kg,
# Simulating time 12.50: dhat =  [20.00705964]
# Fuel left: 0.35 kg,
# Simulating time 12.55: dhat =  [20.08435898]
# Fuel left: 0.35 kg,
# Simulating time 12.60: dhat =  [20.16153934]
# Fuel left: 0.35 kg,
# Simulating time 12.65: dhat =  [20.23860072]
# Fuel left: 0.35 kg,
# Simulating time 12.70: dhat =  [20.31554314]
# Fuel left: 0.35 kg,
# Simulating time 12.75: dhat =  [20.3923666]
# Fuel left: 0.34 kg,
# Simulating time 12.80: dhat =  [20.46907114]
# Fuel left: 0.34 kg,
# Simulating time 12.85: dhat =  [20.54565677]
# Fuel left: 0.34 kg,
# Simulating time 12.90: dhat =  [20.62212352]
# Fuel left: 0.34 kg,
# Simulating time 12.95: dhat =  [20.6984714]
# Fuel left: 0.33 kg,
# Simulating time 13.00: dhat =  [20.77470046]
# Fuel left: 0.33 kg,
# Simulating time 13.05: dhat =  [20.85081071]
# Fuel left: 0.33 kg,
# Simulating time 13.10: dhat =  [20.92680221]
# Fuel left: 0.33 kg,
# Simulating time 13.15: dhat =  [21.00267498]
# Fuel left: 0.33 kg,
# Simulating time 13.20: dhat =  [21.07842907]
# Fuel left: 0.32 kg,
# Simulating time 13.25: dhat =  [21.15406451]
# Fuel left: 0.32 kg,
# Simulating time 13.30: dhat =  [21.22958136]
# Fuel left: 0.32 kg,
# Simulating time 13.35: dhat =  [21.30497966]
# Fuel left: 0.32 kg,
# Simulating time 13.40: dhat =  [21.38025947]
# Fuel left: 0.31 kg,
# Simulating time 13.45: dhat =  [21.45542083]
# Fuel left: 0.31 kg,
# Simulating time 13.50: dhat =  [21.5304638]
# Fuel left: 0.31 kg,
# Simulating time 13.55: dhat =  [21.60538844]
# Fuel left: 0.31 kg,
# Simulating time 13.60: dhat =  [21.68019481]
# Fuel left: 0.31 kg,
# Simulating time 13.65: dhat =  [21.75488297]
# Fuel left: 0.30 kg,
# Simulating time 13.70: dhat =  [21.82945299]
# Fuel left: 0.30 kg,
# Simulating time 13.75: dhat =  [21.90390493]
# Fuel left: 0.30 kg,
# Simulating time 13.80: dhat =  [21.97823887]
# Fuel left: 0.30 kg,
# Simulating time 13.85: dhat =  [22.05245487]
# Fuel left: 0.30 kg,
# Simulating time 13.90: dhat =  [22.12655301]
# Fuel left: 0.29 kg,
# Simulating time 13.95: dhat =  [22.20053337]
# Fuel left: 0.29 kg,
# Simulating time 14.00: dhat =  [22.27439602]
# Fuel left: 0.29 kg,
# Simulating time 14.05: dhat =  [22.34814105]
# Fuel left: 0.29 kg,
# Simulating time 14.10: dhat =  [22.42176853]
# Fuel left: 0.28 kg,
# Simulating time 14.15: dhat =  [22.49527855]
# Fuel left: 0.28 kg,
# Simulating time 14.20: dhat =  [22.5686712]
# Fuel left: 0.28 kg,
# Simulating time 14.25: dhat =  [22.64194656]
# Fuel left: 0.28 kg,
# Simulating time 14.30: dhat =  [22.71510473]
# Fuel left: 0.28 kg,
# Simulating time 14.35: dhat =  [22.78814579]
# Fuel left: 0.27 kg,
# Simulating time 14.40: dhat =  [22.86106985]
# Fuel left: 0.27 kg,
# Simulating time 14.45: dhat =  [22.93387698]
# Fuel left: 0.27 kg,
# Simulating time 14.50: dhat =  [23.0065673]
# Fuel left: 0.27 kg,
# Simulating time 14.55: dhat =  [23.07914091]
# Fuel left: 0.27 kg,
# Simulating time 14.60: dhat =  [23.15159789]
# Fuel left: 0.26 kg,
# Simulating time 14.65: dhat =  [23.22393836]
# Fuel left: 0.26 kg,
# Simulating time 14.70: dhat =  [23.29616241]
# Fuel left: 0.26 kg,
# Simulating time 14.75: dhat =  [23.36827016]
# Fuel left: 0.26 kg,
# Simulating time 14.80: dhat =  [23.44026171]
# Fuel left: 0.25 kg,
# Simulating time 14.85: dhat =  [23.51213716]
# Fuel left: 0.25 kg,
# Simulating time 14.90: dhat =  [23.58389664]
# Fuel left: 0.25 kg,
# Simulating time 14.95: dhat =  [23.65554024]
# Fuel left: 0.25 kg,
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', interval=200, max=299, step=4), Int…

# %%
plot_static_states_inputs(t_cl[:-1], x_cl[:,:-1], u_cl, ref[:,:-1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
