# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from LinearMPC_5.MPCVelControl import MPCVelControl
from PIControl.PIControl import PIControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 15; H = 5
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 1.5
rocket.fuel_rate = 0  

t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
# c:\Users\ayoub\anaconda3\envs\mpc\Lib\site-packages\cvxpy\problems\problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Simulating time 0.00:
# c:\Users\ayoub\anaconda3\envs\mpc\Lib\site-packages\cvxpy\reductions\solvers\solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# dhat =  [6.79855871]
#
# Simulating time 0.05: dhat =  [6.79855871]
#
# Simulating time 0.10: dhat =  [6.79855871]
#
# Simulating time 0.15: dhat =  [6.79855871]
#
# Simulating time 0.20: dhat =  [6.79855871]
#
# Simulating time 0.25: dhat =  [6.79855871]
#
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.30: dhat =  [6.79855871]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.19 > 0.17,
# Simulating time 0.35: dhat =  [6.79855871]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.40: dhat =  [6.79855871]
#
# Simulating time 0.45: dhat =  [6.79855871]
#
# Simulating time 0.50: dhat =  [6.79855871]
#
# Simulating time 0.55: dhat =  [6.79855871]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.60: dhat =  [6.79855871]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.65: dhat =  [6.79855871]
#
#  State beta violation: -0.17 < -0.17,
# Simulating time 0.70: dhat =  [6.79855871]
#
# Simulating time 0.75: dhat =  [6.79855871]
#
# Simulating time 0.80: dhat =  [6.79855871]
#
# Simulating time 0.85: dhat =  [6.79855871]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.90: dhat =  [6.79855871]
#
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.95: dhat =  [6.79855871]
#
# Simulating time 1.00: dhat =  [6.79855871]
#
# Simulating time 1.05: dhat =  [6.79855871]
#
# Simulating time 1.10: dhat =  [6.79855871]
#
# Simulating time 1.15: dhat =  [6.79855871]
#
# Simulating time 1.20: dhat =  [6.79855871]
#
# Simulating time 1.25: dhat =  [6.79855871]
#
# Simulating time 1.30: dhat =  [6.79855871]
#
# Simulating time 1.35: dhat =  [6.79855871]
#
# Simulating time 1.40: dhat =  [6.79855871]
#
# Simulating time 1.45: dhat =  [6.79855871]
#
# Simulating time 1.50: dhat =  [6.79855871]
#
# Simulating time 1.55: dhat =  [6.79855871]
#
# Simulating time 1.60: dhat =  [6.79855871]
#
# Simulating time 1.65: dhat =  [6.79855871]
#
# Simulating time 1.70: dhat =  [6.79855871]
#
# Simulating time 1.75: dhat =  [6.79855871]
#
# Simulating time 1.80: dhat =  [6.79855871]
#
# Simulating time 1.85: dhat =  [6.79855871]
#
# Simulating time 1.90: dhat =  [6.79855871]
#
# Simulating time 1.95: dhat =  [6.79855871]
#
# Simulating time 2.00: dhat =  [6.79855871]
#
# Simulating time 2.05: dhat =  [6.79855871]
#
# Simulating time 2.10: dhat =  [6.79855871]
#
# Simulating time 2.15: dhat =  [6.96896382]
#
# Simulating time 2.20: dhat =  [7.13818607]
#
# Simulating time 2.25: dhat =  [7.30591649]
#
# Simulating time 2.30: dhat =  [7.47188895]
#
# Simulating time 2.35: dhat =  [7.63587575]
#
# Simulating time 2.40: dhat =  [7.79768372]
#
# Simulating time 2.45: dhat =  [7.95715067]
#
# Simulating time 2.50: dhat =  [8.114142]
#
# Simulating time 2.55: dhat =  [8.26854782]
#
# Simulating time 2.60: dhat =  [8.42028018]
#
# Simulating time 2.65: dhat =  [8.56927063]
#
# Simulating time 2.70: dhat =  [8.71546797]
#
# Simulating time 2.75: dhat =  [8.85879792]
#
# Simulating time 2.80: dhat =  [8.99883149]
#
# Simulating time 2.85: dhat =  [9.13536559]
#
# Simulating time 2.90: dhat =  [9.26859258]
#
# Simulating time 2.95: dhat =  [9.39888422]
#
# Simulating time 3.00: dhat =  [9.5266819]
#
# Simulating time 3.05: dhat =  [9.65243902]
#
# Simulating time 3.10: dhat =  [9.77658887]
#
# Simulating time 3.15: dhat =  [9.89952602]
#
# Simulating time 3.20: dhat =  [10.02159533]
#
# Simulating time 3.25: dhat =  [10.14308591]
#
# Simulating time 3.30: dhat =  [10.26422859]
#
# Simulating time 3.35: dhat =  [10.38519593]
#
# Simulating time 3.40: dhat =  [10.50610432]
#
# Simulating time 3.45: dhat =  [10.62701746]
#
# Simulating time 3.50: dhat =  [10.74795098]
#
# Simulating time 3.55: dhat =  [10.86887776]
#
# Simulating time 3.60: dhat =  [10.98973371]
#
# Simulating time 3.65: dhat =  [11.11042374]
#
# Simulating time 3.70: dhat =  [11.23082765]
#
# Simulating time 3.75: dhat =  [11.35080594]
#
# Simulating time 3.80: dhat =  [11.47020521]
#
# Simulating time 3.85: dhat =  [11.58886317]
#
# Simulating time 3.90: dhat =  [11.70661321]
#
# Simulating time 3.95: dhat =  [11.82328842]
#
# Simulating time 4.00: dhat =  [11.93872509]
#
# Simulating time 4.05: dhat =  [12.05276563]
#
# Simulating time 4.10: dhat =  [12.16526103]
#
# Simulating time 4.15: dhat =  [12.27607276]
#
# Simulating time 4.20: dhat =  [12.38507425]
#
# Simulating time 4.25: dhat =  [12.49215192]
#
# Simulating time 4.30: dhat =  [12.59720581]
#
# Simulating time 4.35: dhat =  [12.7001499]
#
# Simulating time 4.40: dhat =  [12.80091217]
#
# Simulating time 4.45: dhat =  [12.89943429]
#
# Simulating time 4.50: dhat =  [12.99567128]
#
# Simulating time 4.55: dhat =  [13.08959081]
#
# Simulating time 4.60: dhat =  [13.18117258]
#
# Simulating time 4.65: dhat =  [13.27040742]
#
# Simulating time 4.70: dhat =  [13.35729641]
#
# Simulating time 4.75: dhat =  [13.44185001]
#
# Simulating time 4.80: dhat =  [13.52408706]
#
# Simulating time 4.85: dhat =  [13.60403386]
#
# Simulating time 4.90: dhat =  [13.68172327]
#
# Simulating time 4.95: dhat =  [13.75719376]
#
# Simulating time 5.00: dhat =  [13.83048866]
#
# Simulating time 5.05: dhat =  [13.90165524]
#
# Simulating time 5.10: dhat =  [13.97074407]
#
# Simulating time 5.15: dhat =  [14.03780825]
#
# Simulating time 5.20: dhat =  [14.10290284]
#
# Simulating time 5.25: dhat =  [14.16608425]
#
# Simulating time 5.30: dhat =  [14.22740974]
#
# Simulating time 5.35: dhat =  [14.28693697]
#
# Simulating time 5.40: dhat =  [14.34472359]
#
# Simulating time 5.45: dhat =  [14.40082691]
#
# Simulating time 5.50: dhat =  [14.45530358]
#
# Simulating time 5.55: dhat =  [14.50820934]
#
# Simulating time 5.60: dhat =  [14.55959884]
#
# Simulating time 5.65: dhat =  [14.60952543]
#
# Simulating time 5.70: dhat =  [14.65804102]
#
# Simulating time 5.75: dhat =  [14.70519601]
#
# Simulating time 5.80: dhat =  [14.7510392]
#
# Simulating time 5.85: dhat =  [14.79561768]
#
# Simulating time 5.90: dhat =  [14.83897688]
#
# Simulating time 5.95: dhat =  [14.88116051]
#
# Simulating time 6.00: dhat =  [14.92221054]
#
# Simulating time 6.05: dhat =  [14.96216726]
#
# Simulating time 6.10: dhat =  [15.00106929]
#
# Simulating time 6.15: dhat =  [15.03895359]
#
# Simulating time 6.20: dhat =  [15.07585553]
#
# Simulating time 6.25: dhat =  [15.11180892]
#
# Simulating time 6.30: dhat =  [15.14684607]
#
# Simulating time 6.35: dhat =  [15.18099784]
#
# Simulating time 6.40: dhat =  [15.2142937]
#
# Simulating time 6.45: dhat =  [15.2467618]
#
# Simulating time 6.50: dhat =  [15.278429]
#
# Simulating time 6.55: dhat =  [15.30932096]
#
# Simulating time 6.60: dhat =  [15.33946216]
#
# Simulating time 6.65: dhat =  [15.36887602]
#
# Simulating time 6.70: dhat =  [15.39758487]
#
# Simulating time 6.75: dhat =  [15.42561008]
#
# Simulating time 6.80: dhat =  [15.45297208]
#
# Simulating time 6.85: dhat =  [15.47969041]
#
# Simulating time 6.90: dhat =  [15.50578377]
#
# Simulating time 6.95: dhat =  [15.53127006]
#
# Simulating time 7.00: dhat =  [15.55616643]
#
# Simulating time 7.05: dhat =  [15.58048935]
#
# Simulating time 7.10: dhat =  [15.60425459]
#
# Simulating time 7.15: dhat =  [15.6274773]
#
# Simulating time 7.20: dhat =  [15.65017204]
#
# Simulating time 7.25: dhat =  [15.67235279]
#
# Simulating time 7.30: dhat =  [15.69403301]
#
# Simulating time 7.35: dhat =  [15.71522566]
#
# Simulating time 7.40: dhat =  [15.73594323]
#
# Simulating time 7.45: dhat =  [15.75619775]
#
# Simulating time 7.50: dhat =  [15.77600082]
#
# Simulating time 7.55: dhat =  [15.79536365]
#
# Simulating time 7.60: dhat =  [15.81429706]
#
# Simulating time 7.65: dhat =  [15.83281153]
#
# Simulating time 7.70: dhat =  [15.85091717]
#
# Simulating time 7.75: dhat =  [15.86862378]
#
# Simulating time 7.80: dhat =  [15.88594085]
#
# Simulating time 7.85: dhat =  [15.90287758]
#
# Simulating time 7.90: dhat =  [15.91944288]
#
# Simulating time 7.95: dhat =  [15.9356454]
#
# Simulating time 8.00: dhat =  [15.95149355]
#
# Simulating time 8.05: dhat =  [15.96699547]
#
# Simulating time 8.10: dhat =  [15.9821591]
#
# Simulating time 8.15: dhat =  [15.99699214]
#
# Simulating time 8.20: dhat =  [16.01150209]
#
# Simulating time 8.25: dhat =  [16.02569622]
#
# Simulating time 8.30: dhat =  [16.03958166]
#
# Simulating time 8.35: dhat =  [16.0531653]
#
# Simulating time 8.40: dhat =  [16.06645387]
#
# Simulating time 8.45: dhat =  [16.07945396]
#
# Simulating time 8.50: dhat =  [16.09217194]
#
# Simulating time 8.55: dhat =  [16.10461406]
#
# Simulating time 8.60: dhat =  [16.1167864]
#
# Simulating time 8.65: dhat =  [16.12869491]
#
# Simulating time 8.70: dhat =  [16.14034536]
#
# Simulating time 8.75: dhat =  [16.15174343]
#
# Simulating time 8.80: dhat =  [16.16289463]
#
# Simulating time 8.85: dhat =  [16.17380435]
#
# Simulating time 8.90: dhat =  [16.18447786]
#
# Simulating time 8.95: dhat =  [16.19492031]
#
# Simulating time 9.00: dhat =  [16.20513672]
#
# Simulating time 9.05: dhat =  [16.21513201]
#
# Simulating time 9.10: dhat =  [16.22491098]
#
# Simulating time 9.15: dhat =  [16.23447832]
#
# Simulating time 9.20: dhat =  [16.24383862]
#
# Simulating time 9.25: dhat =  [16.25299637]
#
# Simulating time 9.30: dhat =  [16.26195595]
#
# Simulating time 9.35: dhat =  [16.27072166]
#
# Simulating time 9.40: dhat =  [16.27929768]
#
# Simulating time 9.45: dhat =  [16.28768813]
#
# Simulating time 9.50: dhat =  [16.29589701]
#
# Simulating time 9.55: dhat =  [16.30392825]
#
# Simulating time 9.60: dhat =  [16.31178568]
#
# Simulating time 9.65: dhat =  [16.31947307]
#
# Simulating time 9.70: dhat =  [16.32699409]
#
# Simulating time 9.75: dhat =  [16.33435233]
#
# Simulating time 9.80: dhat =  [16.3415513]
#
# Simulating time 9.85: dhat =  [16.34859446]
#
# Simulating time 9.90: dhat =  [16.35548516]
#
# Simulating time 9.95: dhat =  [16.3622267]
#
# Simulating time 10.00: dhat =  [16.3688223]
#
# Simulating time 10.05: dhat =  [16.37527512]
#
# Simulating time 10.10: dhat =  [16.38158823]
#
# Simulating time 10.15: dhat =  [16.38776466]
#
# Simulating time 10.20: dhat =  [16.39380736]
#
# Simulating time 10.25: dhat =  [16.39971922]
#
# Simulating time 10.30: dhat =  [16.40550306]
#
# Simulating time 10.35: dhat =  [16.41116166]
#
# Simulating time 10.40: dhat =  [16.41669772]
#
# Simulating time 10.45: dhat =  [16.42211389]
#
# Simulating time 10.50: dhat =  [16.42741277]
#
# Simulating time 10.55: dhat =  [16.43259688]
#
# Simulating time 10.60: dhat =  [16.43766871]
#
# Simulating time 10.65: dhat =  [16.44263069]
#
# Simulating time 10.70: dhat =  [16.44748519]
#
# Simulating time 10.75: dhat =  [16.45223454]
#
# Simulating time 10.80: dhat =  [16.45688101]
#
# Simulating time 10.85: dhat =  [16.46142683]
#
# Simulating time 10.90: dhat =  [16.46587417]
#
# Simulating time 10.95: dhat =  [16.47022518]
#
# Simulating time 11.00: dhat =  [16.47448192]
#
# Simulating time 11.05: dhat =  [16.47864644]
#
# Simulating time 11.10: dhat =  [16.48272075]
#
# Simulating time 11.15: dhat =  [16.48670678]
#
# Simulating time 11.20: dhat =  [16.49060645]
#
# Simulating time 11.25: dhat =  [16.49442163]
#
# Simulating time 11.30: dhat =  [16.49815415]
#
# Simulating time 11.35: dhat =  [16.50180581]
#
# Simulating time 11.40: dhat =  [16.50537834]
#
# Simulating time 11.45: dhat =  [16.50887346]
#
# Simulating time 11.50: dhat =  [16.51229285]
#
# Simulating time 11.55: dhat =  [16.51563816]
#
# Simulating time 11.60: dhat =  [16.51891097]
#
# Simulating time 11.65: dhat =  [16.52211287]
#
# Simulating time 11.70: dhat =  [16.52524539]
#
# Simulating time 11.75: dhat =  [16.52831003]
#
# Simulating time 11.80: dhat =  [16.53130827]
#
# Simulating time 11.85: dhat =  [16.53424153]
#
# Simulating time 11.90: dhat =  [16.53711124]
#
# Simulating time 11.95: dhat =  [16.53991876]
#
# Simulating time 12.00: dhat =  [16.54266544]
#
# Simulating time 12.05: dhat =  [16.5453526]
#
# Simulating time 12.10: dhat =  [16.54798154]
#
# Simulating time 12.15: dhat =  [16.5505535]
#
# Simulating time 12.20: dhat =  [16.55306973]
#
# Simulating time 12.25: dhat =  [16.55553143]
#
# Simulating time 12.30: dhat =  [16.55793979]
#
# Simulating time 12.35: dhat =  [16.56029596]
#
# Simulating time 12.40: dhat =  [16.56260107]
#
# Simulating time 12.45: dhat =  [16.56485623]
#
# Simulating time 12.50: dhat =  [16.56706252]
#
# Simulating time 12.55: dhat =  [16.569221]
#
# Simulating time 12.60: dhat =  [16.5713327]
#
# Simulating time 12.65: dhat =  [16.57339864]
#
# Simulating time 12.70: dhat =  [16.57541981]
#
# Simulating time 12.75: dhat =  [16.57739718]
#
# Simulating time 12.80: dhat =  [16.5793317]
#
# Simulating time 12.85: dhat =  [16.5812243]
#
# Simulating time 12.90: dhat =  [16.58307588]
#
# Simulating time 12.95: dhat =  [16.58488734]
#
# Simulating time 13.00: dhat =  [16.58665955]
#
# Simulating time 13.05: dhat =  [16.58839335]
#
# Simulating time 13.10: dhat =  [16.59008957]
#
# Simulating time 13.15: dhat =  [16.59174904]
#
# Simulating time 13.20: dhat =  [16.59337255]
#
# Simulating time 13.25: dhat =  [16.59496087]
#
# Simulating time 13.30: dhat =  [16.59651478]
#
# Simulating time 13.35: dhat =  [16.59803501]
#
# Simulating time 13.40: dhat =  [16.59952229]
#
# Simulating time 13.45: dhat =  [16.60097735]
#
# Simulating time 13.50: dhat =  [16.60240087]
#
# Simulating time 13.55: dhat =  [16.60379355]
#
# Simulating time 13.60: dhat =  [16.60515604]
#
# Simulating time 13.65: dhat =  [16.60648901]
#
# Simulating time 13.70: dhat =  [16.6077931]
#
# Simulating time 13.75: dhat =  [16.60906892]
#
# Simulating time 13.80: dhat =  [16.61031709]
#
# Simulating time 13.85: dhat =  [16.61153822]
#
# Simulating time 13.90: dhat =  [16.61273288]
#
# Simulating time 13.95: dhat =  [16.61390166]
#
# Simulating time 14.00: dhat =  [16.6150451]
#
# Simulating time 14.05: dhat =  [16.61616377]
#
# Simulating time 14.10: dhat =  [16.61725819]
#
# Simulating time 14.15: dhat =  [16.6183289]
#
# Simulating time 14.20: dhat =  [16.61937641]
#
# Simulating time 14.25: dhat =  [16.62040121]
#
# Simulating time 14.30: dhat =  [16.62140381]
#
# Simulating time 14.35: dhat =  [16.62238468]
#
# Simulating time 14.40: dhat =  [16.62334429]
#
# Simulating time 14.45: dhat =  [16.62428311]
#
# Simulating time 14.50: dhat =  [16.62520158]
#
# Simulating time 14.55: dhat =  [16.62610015]
#
# Simulating time 14.60: dhat =  [16.62697925]
#
# Simulating time 14.65: dhat =  [16.6278393]
#
# Simulating time 14.70: dhat =  [16.62868071]
#
# Simulating time 14.75: dhat =  [16.62950388]
#
# Simulating time 14.80: dhat =  [16.63030922]
#
# Simulating time 14.85: dhat =  [16.6310971]
#
# Simulating time 14.90: dhat =  [16.63186792]
#
# Simulating time 14.95: dhat =  [16.63262202]
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', interval=200, max=299, step=4), Int…
