# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# MPC import
from LinearMPC_5.MPCVelControl import MPCVelControl
from PIControl.PIControl import PIControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 15; H = 5
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 1.5
rocket.fuel_rate = 0  

t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# Simulating time 0.00: dhat =  [24.47481134]
#
# Simulating time 0.05: dhat =  [24.47481134]
#
# Simulating time 0.10: dhat =  [24.47481134]
#
# Simulating time 0.15: dhat =  [24.47481134]
#
# Simulating time 0.20: dhat =  [24.47481134]
#
# Simulating time 0.25: dhat =  [24.47481134]
#
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.30: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.19 > 0.17,
# Simulating time 0.35: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.40: dhat =  [24.47481134]
#
# Simulating time 0.45: dhat =  [24.47481134]
#
# Simulating time 0.50: dhat =  [24.47481134]
#
# Simulating time 0.55: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.60: dhat =  [24.47481134]
#
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17,
# Simulating time 0.65: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17,
# Simulating time 0.70: dhat =  [24.47481134]
#
# Simulating time 0.75: dhat =  [24.47481134]
#
# Simulating time 0.80: dhat =  [24.47481134]
#
# Simulating time 0.85: dhat =  [24.47481134]
#
#  State beta violation: -0.17 < -0.17,
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.90: dhat =  [24.47481134]
#
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.95: dhat =  [24.47481134]
#
# Simulating time 1.00: dhat =  [24.47481134]
#
# Simulating time 1.05: dhat =  [24.47481134]
#
# Simulating time 1.10: dhat =  [24.47481134]
#
# Simulating time 1.15: dhat =  [24.47481134]
#
# Simulating time 1.20: dhat =  [24.47481134]
#
# Simulating time 1.25: dhat =  [24.47481134]
#
# Simulating time 1.30: dhat =  [24.47481134]
#
# Simulating time 1.35: dhat =  [24.47481134]
#
# Simulating time 1.40: dhat =  [24.47481134]
#
# Simulating time 1.45: dhat =  [24.47481134]
#
# Simulating time 1.50: dhat =  [24.47481134]
#
# Simulating time 1.55: dhat =  [24.47481134]
#
# Simulating time 1.60: dhat =  [24.47481134]
#
# Simulating time 1.65: dhat =  [24.47481134]
#
# Simulating time 1.70: dhat =  [24.47481134]
#
# Simulating time 1.75: dhat =  [24.47481134]
#
# Simulating time 1.80: dhat =  [24.47481134]
#
# Simulating time 1.85: dhat =  [24.47481134]
#
# Simulating time 1.90: dhat =  [24.47481134]
#
# Simulating time 1.95: dhat =  [24.47481134]
#
# Simulating time 2.00: dhat =  [24.47481134]
#
# Simulating time 2.05: dhat =  [24.47481134]
#
# Simulating time 2.10: dhat =  [24.47481134]
#
# Simulating time 2.15: dhat =  [24.47481134]
#
# Simulating time 2.20: dhat =  [24.47481134]
#
# Simulating time 2.25: dhat =  [24.47481134]
#
# Simulating time 2.30: dhat =  [24.47481134]
#
# Simulating time 2.35: dhat =  [24.47481134]
#
# Simulating time 2.40: dhat =  [24.47481134]
#
# Simulating time 2.45: dhat =  [24.47481134]
#
# Simulating time 2.50: dhat =  [24.47481134]
#
# Simulating time 2.55: dhat =  [24.47481134]
#
# Simulating time 2.60: dhat =  [24.47481134]
#
# Simulating time 2.65: dhat =  [24.47481134]
#
# Simulating time 2.70: dhat =  [24.47481134]
#
# Simulating time 2.75: dhat =  [24.47481134]
#
# Simulating time 2.80: dhat =  [24.47481134]
#
# Simulating time 2.85: dhat =  [24.47481134]
#
# Simulating time 2.90: dhat =  [24.47481134]
#
# Simulating time 2.95: dhat =  [24.47481134]
#
# Simulating time 3.00: dhat =  [24.47481134]
#
# Simulating time 3.05: dhat =  [24.47481134]
#
# Simulating time 3.10: dhat =  [24.47481134]
#
# Simulating time 3.15: dhat =  [24.47481134]
#
# Simulating time 3.20: dhat =  [24.47481134]
#
# Simulating time 3.25: dhat =  [24.47481134]
#
# Simulating time 3.30: dhat =  [24.47481134]
#
# Simulating time 3.35: dhat =  [24.47481134]
#
# Simulating time 3.40: dhat =  [24.47481134]
#
# Simulating time 3.45: dhat =  [24.47481134]
#
# Simulating time 3.50: dhat =  [24.47481134]
#
# Simulating time 3.55: dhat =  [24.47481134]
#
# Simulating time 3.60: dhat =  [24.47481134]
#
# Simulating time 3.65: dhat =  [24.47481134]
#
# Simulating time 3.70: dhat =  [24.47481134]
#
# Simulating time 3.75: dhat =  [24.47481134]
#
# Simulating time 3.80: dhat =  [24.47481134]
#
# Simulating time 3.85: dhat =  [24.47481134]
#
# Simulating time 3.90: dhat =  [24.47481134]
#
# Simulating time 3.95: dhat =  [24.47481134]
#
# Simulating time 4.00: dhat =  [24.47481134]
#
# Simulating time 4.05: dhat =  [24.47481134]
#
# Simulating time 4.10: dhat =  [24.47481134]
#
# Simulating time 4.15: dhat =  [24.47481134]
#
# Simulating time 4.20: dhat =  [23.91052069]
#
# Simulating time 4.25: dhat =  [23.36341362]
#
# Simulating time 4.30: dhat =  [22.84251699]
#
# Simulating time 4.35: dhat =  [22.35276768]
#
# Simulating time 4.40: dhat =  [21.89638453]
#
# Simulating time 4.45: dhat =  [21.47380999]
#
# Simulating time 4.50: dhat =  [21.08435406]
#
# Simulating time 4.55: dhat =  [20.72663272]
#
# Simulating time 4.60: dhat =  [20.39886422]
#
# Simulating time 4.65: dhat =  [20.09906736]
#
# Simulating time 4.70: dhat =  [19.82519238]
#
# Simulating time 4.75: dhat =  [19.57520546]
#
# Simulating time 4.80: dhat =  [19.34714165]
#
# Simulating time 4.85: dhat =  [19.13913629]
#
# Simulating time 4.90: dhat =  [18.94944188]
#
# Simulating time 4.95: dhat =  [18.77643545]
#
# Simulating time 5.00: dhat =  [18.61861954]
#
# Simulating time 5.05: dhat =  [18.47461915]
#
# Simulating time 5.10: dhat =  [18.34317634]
#
# Simulating time 5.15: dhat =  [18.22314336]
#
# Simulating time 5.20: dhat =  [18.11347507]
#
# Simulating time 5.25: dhat =  [18.01322126]
#
# Simulating time 5.30: dhat =  [17.92151895]
#
# Simulating time 5.35: dhat =  [17.83758498]
#
# Simulating time 5.40: dhat =  [17.76070907]
#
# Simulating time 5.45: dhat =  [17.69024725]
#
# Simulating time 5.50: dhat =  [17.62561581]
#
# Simulating time 5.55: dhat =  [17.5662857]
#
# Simulating time 5.60: dhat =  [17.51177741]
#
# Simulating time 5.65: dhat =  [17.46165635]
#
# Simulating time 5.70: dhat =  [17.41552854]
#
# Simulating time 5.75: dhat =  [17.37303678]
#
# Simulating time 5.80: dhat =  [17.33385717]
#
# Simulating time 5.85: dhat =  [17.29769591]
#
# Simulating time 5.90: dhat =  [17.26428644]
#
# Simulating time 5.95: dhat =  [17.23338689]
#
# Simulating time 6.00: dhat =  [17.20477768]
#
# Simulating time 6.05: dhat =  [17.17825945]
#
# Simulating time 6.10: dhat =  [17.15365115]
#
# Simulating time 6.15: dhat =  [17.13078829]
#
# Simulating time 6.20: dhat =  [17.10952142]
#
# Simulating time 6.25: dhat =  [17.08971468]
#
# Simulating time 6.30: dhat =  [17.07124457]
#
# Simulating time 6.35: dhat =  [17.05399877]
#
# Simulating time 6.40: dhat =  [17.0378751]
#
# Simulating time 6.45: dhat =  [17.02278063]
#
# Simulating time 6.50: dhat =  [17.00863075]
#
# Simulating time 6.55: dhat =  [16.99534845]
#
# Simulating time 6.60: dhat =  [16.98286363]
#
# Simulating time 6.65: dhat =  [16.97111243]
#
# Simulating time 6.70: dhat =  [16.96003666]
#
# Simulating time 6.75: dhat =  [16.94958333]
#
# Simulating time 6.80: dhat =  [16.9397041]
#
# Simulating time 6.85: dhat =  [16.93035493]
#
# Simulating time 6.90: dhat =  [16.92149564]
#
# Simulating time 6.95: dhat =  [16.91308955]
#
# Simulating time 7.00: dhat =  [16.90510322]
#
# Simulating time 7.05: dhat =  [16.89750608]
#
# Simulating time 7.10: dhat =  [16.89027023]
#
# Simulating time 7.15: dhat =  [16.88337016]
#
# Simulating time 7.20: dhat =  [16.87678257]
#
# Simulating time 7.25: dhat =  [16.8704861]
#
# Simulating time 7.30: dhat =  [16.86446125]
#
# Simulating time 7.35: dhat =  [16.85869013]
#
# Simulating time 7.40: dhat =  [16.85315635]
#
# Simulating time 7.45: dhat =  [16.84784489]
#
# Simulating time 7.50: dhat =  [16.84274195]
#
# Simulating time 7.55: dhat =  [16.83783487]
#
# Simulating time 7.60: dhat =  [16.83311202]
#
# Simulating time 7.65: dhat =  [16.82856267]
#
# Simulating time 7.70: dhat =  [16.82417697]
#
# Simulating time 7.75: dhat =  [16.81994583]
#
# Simulating time 7.80: dhat =  [16.81586087]
#
# Simulating time 7.85: dhat =  [16.81191433]
#
# Simulating time 7.90: dhat =  [16.80809907]
#
# Simulating time 7.95: dhat =  [16.80440846]
#
# Simulating time 8.00: dhat =  [16.80083635]
#
# Simulating time 8.05: dhat =  [16.79737705]
#
# Simulating time 8.10: dhat =  [16.79402528]
#
# Simulating time 8.15: dhat =  [16.7907761]
#
# Simulating time 8.20: dhat =  [16.78762494]
#
# Simulating time 8.25: dhat =  [16.78456752]
#
# Simulating time 8.30: dhat =  [16.78159986]
#
# Simulating time 8.35: dhat =  [16.77871823]
#
# Simulating time 8.40: dhat =  [16.77591913]
#
# Simulating time 8.45: dhat =  [16.77319929]
#
# Simulating time 8.50: dhat =  [16.77055564]
#
# Simulating time 8.55: dhat =  [16.76798529]
#
# Simulating time 8.60: dhat =  [16.76548552]
#
# Simulating time 8.65: dhat =  [16.76305376]
#
# Simulating time 8.70: dhat =  [16.7606876]
#
# Simulating time 8.75: dhat =  [16.75838475]
#
# Simulating time 8.80: dhat =  [16.75614304]
#
# Simulating time 8.85: dhat =  [16.75396042]
#
# Simulating time 8.90: dhat =  [16.75183495]
#
# Simulating time 8.95: dhat =  [16.74976477]
#
# Simulating time 9.00: dhat =  [16.74774812]
#
# Simulating time 9.05: dhat =  [16.74578332]
#
# Simulating time 9.10: dhat =  [16.74386879]
#
# Simulating time 9.15: dhat =  [16.74200298]
#
# Simulating time 9.20: dhat =  [16.74018444]
#
# Simulating time 9.25: dhat =  [16.73841177]
#
# Simulating time 9.30: dhat =  [16.73668364]
#
# Simulating time 9.35: dhat =  [16.73499875]
#
# Simulating time 9.40: dhat =  [16.73335589]
#
# Simulating time 9.45: dhat =  [16.73175386]
#
# Simulating time 9.50: dhat =  [16.73019152]
#
# Simulating time 9.55: dhat =  [16.72866778]
#
# Simulating time 9.60: dhat =  [16.7271816]
#
# Simulating time 9.65: dhat =  [16.72573193]
#
# Simulating time 9.70: dhat =  [16.72431782]
#
# Simulating time 9.75: dhat =  [16.72293831]
#
# Simulating time 9.80: dhat =  [16.72159248]
#
# Simulating time 9.85: dhat =  [16.72027944]
#
# Simulating time 9.90: dhat =  [16.71899836]
#
# Simulating time 9.95: dhat =  [16.71774838]
#
# Simulating time 10.00: dhat =  [16.71652872]
#
# Simulating time 10.05: dhat =  [16.71533859]
#
# Simulating time 10.10: dhat =  [16.71417724]
#
# Simulating time 10.15: dhat =  [16.71304395]
#
# Simulating time 10.20: dhat =  [16.71193799]
#
# Simulating time 10.25: dhat =  [16.71085869]
#
# Simulating time 10.30: dhat =  [16.70980537]
#
# Simulating time 10.35: dhat =  [16.70877739]
#
# Simulating time 10.40: dhat =  [16.70777412]
#
# Simulating time 10.45: dhat =  [16.70679493]
#
# Simulating time 10.50: dhat =  [16.70583924]
#
# Simulating time 10.55: dhat =  [16.70490647]
#
# Simulating time 10.60: dhat =  [16.70399604]
#
# Simulating time 10.65: dhat =  [16.70310742]
#
# Simulating time 10.70: dhat =  [16.70224007]
#
# Simulating time 10.75: dhat =  [16.70139347]
#
# Simulating time 10.80: dhat =  [16.70056712]
#
# Simulating time 10.85: dhat =  [16.69976051]
#
# Simulating time 10.90: dhat =  [16.69897317]
#
# Simulating time 10.95: dhat =  [16.69820464]
#
# Simulating time 11.00: dhat =  [16.69745445]
#
# Simulating time 11.05: dhat =  [16.69672216]
#
# Simulating time 11.10: dhat =  [16.69600735]
#
# Simulating time 11.15: dhat =  [16.69530958]
#
# Simulating time 11.20: dhat =  [16.69462845]
#
# Simulating time 11.25: dhat =  [16.69396356]
#
# Simulating time 11.30: dhat =  [16.69331452]
#
# Simulating time 11.35: dhat =  [16.69268093]
#
# Simulating time 11.40: dhat =  [16.69206245]
#
# Simulating time 11.45: dhat =  [16.69145869]
#
# Simulating time 11.50: dhat =  [16.69086931]
#
# Simulating time 11.55: dhat =  [16.69029397]
#
# Simulating time 11.60: dhat =  [16.68973232]
#
# Simulating time 11.65: dhat =  [16.68918404]
#
# Simulating time 11.70: dhat =  [16.68864881]
#
# Simulating time 11.75: dhat =  [16.68812631]
#
# Simulating time 11.80: dhat =  [16.68761625]
#
# Simulating time 11.85: dhat =  [16.68711833]
#
# Simulating time 11.90: dhat =  [16.68663225]
#
# Simulating time 11.95: dhat =  [16.68615773]
#
# Simulating time 12.00: dhat =  [16.6856945]
#
# Simulating time 12.05: dhat =  [16.68524229]
#
# Simulating time 12.10: dhat =  [16.68480083]
#
# Simulating time 12.15: dhat =  [16.68436987]
#
# Simulating time 12.20: dhat =  [16.68394916]
#
# Simulating time 12.25: dhat =  [16.68353845]
#
# Simulating time 12.30: dhat =  [16.68313751]
#
# Simulating time 12.35: dhat =  [16.6827461]
#
# Simulating time 12.40: dhat =  [16.68236399]
#
# Simulating time 12.45: dhat =  [16.68199097]
#
# Simulating time 12.50: dhat =  [16.68162682]
#
# Simulating time 12.55: dhat =  [16.68127132]
#
# Simulating time 12.60: dhat =  [16.68092428]
#
# Simulating time 12.65: dhat =  [16.68058548]
#
# Simulating time 12.70: dhat =  [16.68025473]
#
# Simulating time 12.75: dhat =  [16.67993185]
#
# Simulating time 12.80: dhat =  [16.67961664]
#
# Simulating time 12.85: dhat =  [16.67930893]
#
# Simulating time 12.90: dhat =  [16.67900852]
#
# Simulating time 12.95: dhat =  [16.67871526]
#
# Simulating time 13.00: dhat =  [16.67842897]
#
# Simulating time 13.05: dhat =  [16.67814948]
#
# Simulating time 13.10: dhat =  [16.67787663]
#
# Simulating time 13.15: dhat =  [16.67761027]
#
# Simulating time 13.20: dhat =  [16.67735023]
#
# Simulating time 13.25: dhat =  [16.67709638]
#
# Simulating time 13.30: dhat =  [16.67684856]
#
# Simulating time 13.35: dhat =  [16.67660662]
#
# Simulating time 13.40: dhat =  [16.67637044]
#
# Simulating time 13.45: dhat =  [16.67613987]
#
# Simulating time 13.50: dhat =  [16.67591478]
#
# Simulating time 13.55: dhat =  [16.67569504]
#
# Simulating time 13.60: dhat =  [16.67548051]
#
# Simulating time 13.65: dhat =  [16.67527109]
#
# Simulating time 13.70: dhat =  [16.67506664]
#
# Simulating time 13.75: dhat =  [16.67486705]
#
# Simulating time 13.80: dhat =  [16.67467221]
#
# Simulating time 13.85: dhat =  [16.67448199]
#
# Simulating time 13.90: dhat =  [16.6742963]
#
# Simulating time 13.95: dhat =  [16.67411501]
#
# Simulating time 14.00: dhat =  [16.67393803]
#
# Simulating time 14.05: dhat =  [16.67376526]
#
# Simulating time 14.10: dhat =  [16.6735966]
#
# Simulating time 14.15: dhat =  [16.67343194]
#
# Simulating time 14.20: dhat =  [16.67327119]
#
# Simulating time 14.25: dhat =  [16.67311427]
#
# Simulating time 14.30: dhat =  [16.67296107]
#
# Simulating time 14.35: dhat =  [16.67281151]
#
# Simulating time 14.40: dhat =  [16.67266551]
#
# Simulating time 14.45: dhat =  [16.67252297]
#
# Simulating time 14.50: dhat =  [16.67238382]
#
# Simulating time 14.55: dhat =  [16.67224798]
#
# Simulating time 14.60: dhat =  [16.67211537]
#
# Simulating time 14.65: dhat =  [16.67198591]
#
# Simulating time 14.70: dhat =  [16.67185952]
#
# Simulating time 14.75: dhat =  [16.67173613]
#
# Simulating time 14.80: dhat =  [16.67161568]
#
# Simulating time 14.85: dhat =  [16.67149809]
#
# Simulating time 14.90: dhat =  [16.6713833]
#
# Simulating time 14.95: dhat =  [16.67127123]
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', interval=200, max=299, step=4), Int…
